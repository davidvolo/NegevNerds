# %%
import sys
import os

# Add the Backend directory dynamically
current_dir = os.getcwd()  # Get the current working directory
sys.path.insert(0, os.path.abspath(os.path.join(current_dir, '../..')))

# Import the required modules
from BusinessLayer.NegevNerds import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       6 sys.path.insert(0, os.path.abspath(os.path.join(current_dir, '../../..')))
#       8 # Import the required modules
# ----> 9 from BusinessLayer.NegevNerds import *
#
# ModuleNotFoundError: No module named 'BusinessLayer'

# %%
negevnerd = NegevNerds(mkdir="some_directory_path")
courses = negevnerd.courseFacade.courses
len(courses)
# Out:
# 0

# %%
course_id = "202.1.1031"
course_name = "מבני נתונים"
sylabus_path = "/Users/davidvolodarsky/Desktop/Semeters/Semester_G/NegevNerds/sylbus_analyzer/data_strcutre.pdf"
user_id = "2233"

# %%
negevnerd.open_course(user_id,course_id, course_name, sylabus_path)
# Out:
# 'Error: Course 202.1.1031 is already exist.'

# %%
courses = negevnerd.courseFacade.courses
len(courses)
# Out:
# 0
