# %%
import sys
import os

# Add the Backend directory dynamically
current_dir = os.getcwd()  # Get the current working directory
sys.path.insert(0, os.path.abspath(os.path.join(current_dir, '../..')))

# Import the required modules
from BusinessLayer.PDFAnalyzer.InformationRetrival   import *

# %%
# Example of common words for both languages
common_words_en = {"the", "and", "is", "in", "of", "to","or", "a", "on", "yes", "no", "etc", "it"}
common_words_he = {"של", "הוא", "היא", "זה", "את", "אם","עם", "או","כי"}

# Create an instance of the WordIndex
word_index = WordIndex(common_words_en, common_words_he)

word_index.hebrew_dict

pdf1 = "/Users/davidvolodarsky/Downloads/2019-Moed-B.pdf"

word_index.process_pdf(pdf1, "question_dto1")
word_index.process_pdf(pdf1, "question_dto2")

word_index.english_dict
# Out:
# {'additional': ['question_dto1', 'question_dto2'],
#  'all': ['question_dto1', 'question_dto2'],
#  'BinarySemphore': ['question_dto1', 'question_dto2'],
#  'boolean': ['question_dto1', 'question_dto2'],
#  'busy': ['question_dto1', 'question_dto2'],
#  'child': ['question_dto1', 'question_dto2'],
#  'condition': ['question_dto1', 'question_dto2'],
#  'Critical': ['question_dto1', 'question_dto2'],
#  'cv': ['question_dto1', 'question_dto2'],
#  'd': ['question_dto1', 'question_dto2'],
#  'do': ['question_dto1', 'question_dto2'],
#  'down': ['question_dto1', 'question_dto2'],
#  'false': ['question_dto1', 'question_dto2'],
#  'file': ['question_dto1', 'question_dto2'],
#  'for': ['question_dto1', 'question_dto2'],
#  'fork': ['question_dto1', 'question_dto2'],
#  'free': ['question_dto1', 'question_dto2'],
#  'Global': ['question_dto1', 'question_dto2'],
#  'global': ['question_dto1', 'question_dto2'],
#  'i': ['question_dto1', 'question_dto2'],
#  'if': ['question_dto1', 'question_dto2'],
#  'ii': ['question_dto1', 'question_dto2'],
#  'iii': ['question_dto1', 'question_dto2'],
#  'initially': ['question_dto1', 'question_dto2'],
#  'int': ['question_dto1', 'question_dto2'],
#  'KB': ['question_dto1', 'question_dto2'],
#  'link': ['question_dto1', 'question_dto2'],
#  'lock': ['question_dto1', 'question_dto2'],
#  'main': ['question_dto1', 'question_dto2'],
#  'MB': ['question_dto1', 'question_dto2'],
#  'Monitor': ['question_dto1', 'question_dto2'],
#  'mutex': ['question_dto1', 'question_dto2'],
#  'n': ['question_dto1', 'question_dto2'],
#  'out': ['question_dto1', 'question_dto2'],
#  'paging': ['question_dto1', 'question_dto2'],
#  'printf': ['question_dto1', 'question_dto2'],
#  'privileged': ['question_dto1', 'question_dto2'],
#  'process': ['question_dto1', 'question_dto2'],
#  'processes': ['question_dto1', 'question_dto2'],
#  'Program': ['question_dto1', 'question_dto2'],
#  'return': ['question_dto1', 'question_dto2'],
#  'section': ['question_dto1', 'question_dto2'],
#  'sensitive': ['question_dto1', 'question_dto2'],
#  'shared': ['question_dto1', 'question_dto2'],
#  'signal': ['question_dto1', 'question_dto2'],
#  'soft': ['question_dto1', 'question_dto2'],
#  'sparse': ['question_dto1', 'question_dto2'],
#  'swap': ['question_dto1', 'question_dto2'],
#  'terminate': ['question_dto1', 'question_dto2'],
#  'threads': ['question_dto1', 'question_dto2'],
#  'trap': ['question_dto1', 'question_dto2'],
#  'true': ['question_dto1', 'question_dto2'],
#  'turn': ['question_dto1', 'question_dto2'],
#  'Two': ['question_dto1', 'question_dto2'],
#  'unlock': ['question_dto1', 'question_dto2'],
#  'up': ['question_dto1', 'question_dto2'],
#  'usr': ['question_dto1', 'question_dto2'],
#  'variable': ['question_dto1', 'question_dto2'],
#  'variables': ['question_dto1', 'question_dto2'],
#  'void': ['question_dto1', 'question_dto2'],
#  'Wait': ['question_dto1', 'question_dto2'],
#  'wait': ['question_dto1', 'question_dto2'],
#  'while': ['question_dto1', 'question_dto2'],
#  'X': ['question_dto1', 'question_dto2']}
